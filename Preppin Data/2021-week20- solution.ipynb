# %%
# https://preppindata.blogspot.com/2021/05/2021-week-20-controlling-complaints.html

import pandas as pd
import numpy as np

# %% [markdown]
# ### Input the data file

# %%
df = pd.read_csv(r'data\PD 2021 Wk 20 Input.csv')
df
# Out:
#            Date  Week  Complaints          Department
# 0    19/04/2021    16          42           Ticketing
# 1    20/04/2021    16          32           Ticketing
# 2    21/04/2021    16          51           Ticketing
# 3    22/04/2021    16          48           Ticketing
# 4    23/04/2021    16          34           Ticketing
# ..          ...   ...         ...                 ...
# 100  19/05/2021    20          14  Airport Experience
# 101  20/05/2021    20          19  Airport Experience
# 102  21/05/2021    20          23  Airport Experience
# 103  22/05/2021    20          20  Airport Experience
# 104  23/05/2021    20          17  Airport Experience
#
# [105 rows x 4 columns]

# %% [markdown]
# ### Function for transformation

# %%
def df_std_n(n):
    df_cal['The Upper Control Limit'] = df_cal['Mean'] + n * df_cal['Standard Deviation']
    df_cal['The Lower Control Limit'] = df_cal['Mean'] - n * df_cal['Standard Deviation']
    df_cal['Variation'] = df_cal['The Upper Control Limit'] - df_cal['The Lower Control Limit']

    df_output = pd.merge(df, df_cal, on='Week')
    df_output['Outlier?'] = np.where((df_output['Complaints']>df_output['The Upper Control Limit']) | (df_output['Complaints']<df_output['The Lower Control Limit'])
                                , 'Outside','Inside')
    df_output = df_output[df_output['Outlier?']=='Outside']

    df_output = df_output[['Variation','Outlier?', 'The Lower Control Limit','The Upper Control Limit','Standard Deviation','Mean','Date','Week','Complaints','Department']]
    Variation_label = 'Variation ('+str(n)+'SD)'
    Outlier_label = 'Outlier? ('+str(n)+'SD)'

    df_output.rename(columns={'Variation':Variation_label, 'Outlier?': Outlier_label},inplace=True)
    return df_output

# %% [markdown]
# ### Produce a separate output worksheet (or csv) for 1, 2 or 3 standard deviations and remove the irrelevant fields for that output.

# %%
#testing
df_std_n(2)
# Out:
#     Variation (2SD) Outlier? (2SD)  The Lower Control Limit  \
# 5         51.832698        Outside                 3.797937
# 31        66.484513        Outside                 4.567267
# 43        37.785359        Outside                34.440654
# 74       150.644583        Outside                -2.846101
# 89        48.939224        Outside                 4.435150
#
#     The Upper Control Limit  Standard Deviation       Mean        Date  Week  \
# 5                 55.630635           12.958174  29.714286  24/04/2021    16
# 31                71.051780           16.621128  37.809524  29/04/2021    17
# 43                72.226013            9.446340  53.333333  04/05/2021    18
# 74               147.798482           37.661146  72.476190  14/05/2021    19
# 89                53.374374           12.234806  28.904762  22/05/2021    20
#
#     Complaints          Department
# 5           57           Ticketing
# 31          84  Onboard Experience
# 43          76           Ticketing
# 74         230  Onboard Experience
# 89          68           Ticketing

# %%
df_std_n(1).to_csv(r'output/2021-week20-output1.csv')
df_std_n(2).to_csv(r'output/2021-week20-output2.csv')
df_std_n(3).to_csv(r'output/2021-week20-output3.csv')

# %% [markdown]
# ------
# # The following is the function Breakdown

# %% [markdown]
# ### Create the mean and standard deviation for each Week

# %%
df_cal = df.groupby('Week')['Complaints'].agg(['mean', 'std']).reset_index()
df_cal.rename(columns={'mean':'Mean','std':'Standard Deviation'},inplace=True)

# %% [markdown]
# ### Create the following calculations for each of 1, 2 and 3 standard deviations:
# - The Upper Control Limit (mean+(n*standard deviation))
# - The Lower Control Limit (mean-(n*standard deviation))
# - Variation (Upper Control Limit - Lower Control Limit)

# %%
df_cal['The Upper Control Limit'] = df_cal['Mean'] + df_cal['Standard Deviation']
df_cal['The Lower Control Limit'] = df_cal['Mean'] - df_cal['Standard Deviation']
df_cal['Variation'] = df_cal['The Upper Control Limit'] - df_cal['The Lower Control Limit']

df_cal
# Out:
#    Week       Mean  Standard Deviation  The Upper Control Limit  \
# 0    16  29.714286           12.958174                42.672460
# 1    17  37.809524           16.621128                54.430652
# 2    18  53.333333            9.446340                62.779673
# 3    19  72.476190           37.661146               110.137336
# 4    20  28.904762           12.234806                41.139568
#
#    The Lower Control Limit  Variation
# 0                16.756111  25.916349
# 1                21.188396  33.242257
# 2                43.886994  18.892679
# 3                34.815045  75.322292
# 4                16.669956  24.469612

# %% [markdown]
# ### Join the original data set back on to these results

# %%
df_output = pd.merge(df, df_cal, on='Week')
df_output
# Out:
#            Date  Week  Complaints          Department       Mean  \
# 0    19/04/2021    16          42           Ticketing  29.714286
# 1    20/04/2021    16          32           Ticketing  29.714286
# 2    21/04/2021    16          51           Ticketing  29.714286
# 3    22/04/2021    16          48           Ticketing  29.714286
# 4    23/04/2021    16          34           Ticketing  29.714286
# ..          ...   ...         ...                 ...        ...
# 100  19/05/2021    20          14  Airport Experience  28.904762
# 101  20/05/2021    20          19  Airport Experience  28.904762
# 102  21/05/2021    20          23  Airport Experience  28.904762
# 103  22/05/2021    20          20  Airport Experience  28.904762
# 104  23/05/2021    20          17  Airport Experience  28.904762
#
#      Standard Deviation  The Upper Control Limit  The Lower Control Limit  \
# 0             12.958174                42.672460                16.756111
# 1             12.958174                42.672460                16.756111
# 2             12.958174                42.672460                16.756111
# 3             12.958174                42.672460                16.756111
# 4             12.958174                42.672460                16.756111
# ..                  ...                      ...                      ...
# 100           12.234806                41.139568                16.669956
# 101           12.234806                41.139568                16.669956
# 102           12.234806                41.139568                16.669956
# 103           12.234806                41.139568                16.669956
# 104           12.234806                41.139568                16.669956
#
#      Variation
# 0    25.916349
# 1    25.916349
# 2    25.916349
# 3    25.916349
# 4    25.916349
# ..         ...
# 100  24.469612
# 101  24.469612
# 102  24.469612
# 103  24.469612
# 104  24.469612
#
# [105 rows x 9 columns]

# %% [markdown]
# ### Assess whether each of the complaint values for each Department, Week and Date is within or outside of the control limits

# %%
df_output['Outlier?'] = np.where((df_output['Complaints']>df_output['The Upper Control Limit']) | (df_output['Complaints']<df_output['The Lower Control Limit'])
                                , 'Outside','Inside')
df_output
# Out:
#            Date  Week  Complaints          Department       Mean  \
# 0    19/04/2021    16          42           Ticketing  29.714286
# 1    20/04/2021    16          32           Ticketing  29.714286
# 2    21/04/2021    16          51           Ticketing  29.714286
# 3    22/04/2021    16          48           Ticketing  29.714286
# 4    23/04/2021    16          34           Ticketing  29.714286
# ..          ...   ...         ...                 ...        ...
# 100  19/05/2021    20          14  Airport Experience  28.904762
# 101  20/05/2021    20          19  Airport Experience  28.904762
# 102  21/05/2021    20          23  Airport Experience  28.904762
# 103  22/05/2021    20          20  Airport Experience  28.904762
# 104  23/05/2021    20          17  Airport Experience  28.904762
#
#      Standard Deviation  The Upper Control Limit  The Lower Control Limit  \
# 0             12.958174                42.672460                16.756111
# 1             12.958174                42.672460                16.756111
# 2             12.958174                42.672460                16.756111
# 3             12.958174                42.672460                16.756111
# 4             12.958174                42.672460                16.756111
# ..                  ...                      ...                      ...
# 100           12.234806                41.139568                16.669956
# 101           12.234806                41.139568                16.669956
# 102           12.234806                41.139568                16.669956
# 103           12.234806                41.139568                16.669956
# 104           12.234806                41.139568                16.669956
#
#      Variation Outlier?
# 0    25.916349   Inside
# 1    25.916349   Inside
# 2    25.916349  Outside
# 3    25.916349  Outside
# 4    25.916349   Inside
# ..         ...      ...
# 100  24.469612  Outside
# 101  24.469612   Inside
# 102  24.469612   Inside
# 103  24.469612   Inside
# 104  24.469612   Inside
#
# [105 rows x 10 columns]

# %% [markdown]
# ### Output only Outliers

# %%
df_output = df_output[df_output['Outlier?']=='Outside']
df_output
# Out:
#            Date  Week  Complaints          Department       Mean  \
# 2    21/04/2021    16          51           Ticketing  29.714286
# 3    22/04/2021    16          48           Ticketing  29.714286
# 5    24/04/2021    16          57           Ticketing  29.714286
# 15   20/04/2021    16          12  Airport Experience  29.714286
# 16   21/04/2021    16          10  Airport Experience  29.714286
# 18   23/04/2021    16          14  Airport Experience  29.714286
# 21   26/04/2021    17          14           Ticketing  37.809524
# 23   28/04/2021    17          57           Ticketing  37.809524
# 25   30/04/2021    17          56           Ticketing  37.809524
# 27   02/05/2021    17          59           Ticketing  37.809524
# 31   29/04/2021    17          84  Onboard Experience  37.809524
# 35   26/04/2021    17          20  Airport Experience  37.809524
# 43   04/05/2021    18          76           Ticketing  53.333333
# 45   06/05/2021    18          68           Ticketing  53.333333
# 46   07/05/2021    18          63           Ticketing  53.333333
# 47   08/05/2021    18          65           Ticketing  53.333333
# 49   03/05/2021    18          43  Onboard Experience  53.333333
# 53   07/05/2021    18          42  Onboard Experience  53.333333
# 56   03/05/2021    18          41  Airport Experience  53.333333
# 59   06/05/2021    18          42  Airport Experience  53.333333
# 74   14/05/2021    19         230  Onboard Experience  72.476190
# 87   20/05/2021    20          48           Ticketing  28.904762
# 89   22/05/2021    20          68           Ticketing  28.904762
# 100  19/05/2021    20          14  Airport Experience  28.904762
#
#      Standard Deviation  The Upper Control Limit  The Lower Control Limit  \
# 2             12.958174                42.672460                16.756111
# 3             12.958174                42.672460                16.756111
# 5             12.958174                42.672460                16.756111
# 15            12.958174                42.672460                16.756111
# 16            12.958174                42.672460                16.756111
# 18            12.958174                42.672460                16.756111
# 21            16.621128                54.430652                21.188396
# 23            16.621128                54.430652                21.188396
# 25            16.621128                54.430652                21.188396
# 27            16.621128                54.430652                21.188396
# 31            16.621128                54.430652                21.188396
# 35            16.621128                54.430652                21.188396
# 43             9.446340                62.779673                43.886994
# 45             9.446340                62.779673                43.886994
# 46             9.446340                62.779673                43.886994
# 47             9.446340                62.779673                43.886994
# 49             9.446340                62.779673                43.886994
# 53             9.446340                62.779673                43.886994
# 56             9.446340                62.779673                43.886994
# 59             9.446340                62.779673                43.886994
# 74            37.661146               110.137336                34.815045
# 87            12.234806                41.139568                16.669956
# 89            12.234806                41.139568                16.669956
# 100           12.234806                41.139568                16.669956
#
#      Variation Outlier?
# 2    25.916349  Outside
# 3    25.916349  Outside
# 5    25.916349  Outside
# 15   25.916349  Outside
# 16   25.916349  Outside
# 18   25.916349  Outside
# 21   33.242257  Outside
# 23   33.242257  Outside
# 25   33.242257  Outside
# 27   33.242257  Outside
# 31   33.242257  Outside
# 35   33.242257  Outside
# 43   18.892679  Outside
# 45   18.892679  Outside
# 46   18.892679  Outside
# 47   18.892679  Outside
# 49   18.892679  Outside
# 53   18.892679  Outside
# 56   18.892679  Outside
# 59   18.892679  Outside
# 74   75.322292  Outside
# 87   24.469612  Outside
# 89   24.469612  Outside
# 100  24.469612  Outside

# %%
#reorder column and rename
df_output = df_output[['Variation','Outlier?', 'The Lower Control Limit','The Upper Control Limit','Standard Deviation','Mean','Date','Week','Complaints','Department']]
Variation_label = 'Variation ('+str(1)+'SD)'
Outlier_label = 'Outlier? ('+str(1)+'SD)'

df_output.rename(columns={'Variation':Variation_label, 'Outlier?': Outlier_label})
# Out:
#      Variation (1SD) Outlier? (1SD)  The Lower Control Limit  \
# 2          25.916349        Outside                16.756111
# 3          25.916349        Outside                16.756111
# 5          25.916349        Outside                16.756111
# 15         25.916349        Outside                16.756111
# 16         25.916349        Outside                16.756111
# 18         25.916349        Outside                16.756111
# 21         33.242257        Outside                21.188396
# 23         33.242257        Outside                21.188396
# 25         33.242257        Outside                21.188396
# 27         33.242257        Outside                21.188396
# 31         33.242257        Outside                21.188396
# 35         33.242257        Outside                21.188396
# 43         18.892679        Outside                43.886994
# 45         18.892679        Outside                43.886994
# 46         18.892679        Outside                43.886994
# 47         18.892679        Outside                43.886994
# 49         18.892679        Outside                43.886994
# 53         18.892679        Outside                43.886994
# 56         18.892679        Outside                43.886994
# 59         18.892679        Outside                43.886994
# 74         75.322292        Outside                34.815045
# 87         24.469612        Outside                16.669956
# 89         24.469612        Outside                16.669956
# 100        24.469612        Outside                16.669956
#
#      The Upper Control Limit  Standard Deviation       Mean        Date  Week  \
# 2                  42.672460           12.958174  29.714286  21/04/2021    16
# 3                  42.672460           12.958174  29.714286  22/04/2021    16
# 5                  42.672460           12.958174  29.714286  24/04/2021    16
# 15                 42.672460           12.958174  29.714286  20/04/2021    16
# 16                 42.672460           12.958174  29.714286  21/04/2021    16
# 18                 42.672460           12.958174  29.714286  23/04/2021    16
# 21                 54.430652           16.621128  37.809524  26/04/2021    17
# 23                 54.430652           16.621128  37.809524  28/04/2021    17
# 25                 54.430652           16.621128  37.809524  30/04/2021    17
# 27                 54.430652           16.621128  37.809524  02/05/2021    17
# 31                 54.430652           16.621128  37.809524  29/04/2021    17
# 35                 54.430652           16.621128  37.809524  26/04/2021    17
# 43                 62.779673            9.446340  53.333333  04/05/2021    18
# 45                 62.779673            9.446340  53.333333  06/05/2021    18
# 46                 62.779673            9.446340  53.333333  07/05/2021    18
# 47                 62.779673            9.446340  53.333333  08/05/2021    18
# 49                 62.779673            9.446340  53.333333  03/05/2021    18
# 53                 62.779673            9.446340  53.333333  07/05/2021    18
# 56                 62.779673            9.446340  53.333333  03/05/2021    18
# 59                 62.779673            9.446340  53.333333  06/05/2021    18
# 74                110.137336           37.661146  72.476190  14/05/2021    19
# 87                 41.139568           12.234806  28.904762  20/05/2021    20
# 89                 41.139568           12.234806  28.904762  22/05/2021    20
# 100                41.139568           12.234806  28.904762  19/05/2021    20
#
#      Complaints          Department
# 2            51           Ticketing
# 3            48           Ticketing
# 5            57           Ticketing
# 15           12  Airport Experience
# 16           10  Airport Experience
# 18           14  Airport Experience
# 21           14           Ticketing
# 23           57           Ticketing
# 25           56           Ticketing
# 27           59           Ticketing
# 31           84  Onboard Experience
# 35           20  Airport Experience
# 43           76           Ticketing
# 45           68           Ticketing
# 46           63           Ticketing
# 47           65           Ticketing
# 49           43  Onboard Experience
# 53           42  Onboard Experience
# 56           41  Airport Experience
# 59           42  Airport Experience
# 74          230  Onboard Experience
# 87           48           Ticketing
# 89           68           Ticketing
# 100          14  Airport Experience
