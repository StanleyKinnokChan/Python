# %%
# https://preppindata.blogspot.com/2021/06/2021-week-22-answer-smash.html

import pandas as pd
import numpy as np

# %% [markdown]
# ### Input the data

# %%
df_o_airlines = pd.read_excel(r'data\PD 2021 Wk 23 input.xlsx', sheet_name='Airlines')
df_PrepAir = pd.read_excel(r'data\PD 2021 Wk 23 input.xlsx', sheet_name='Prep Air')

# %% [markdown]
# ### Combine Prep Air dataset with other airlines

# %%
df_main = pd.concat([df_o_airlines, df_PrepAir])
df_main
# Out:
#                             Airline CustomerID  \
# 0    Schmeler, Schimmel and Collier    013d950
# 1    Schmeler, Schimmel and Collier    0d25185
# 2    Schmeler, Schimmel and Collier    a1b541d
# 3    Schmeler, Schimmel and Collier    6b24ea8
# 4    Schmeler, Schimmel and Collier    d5f96ab
# ..                              ...        ...
# 179                        Prep Air    afa8aec
# 180                        Prep Air    63e95db
# 181                        Prep Air    e4e2548
# 182                        Prep Air    b9467ee
# 183                        Prep Air    08d8adc
#
#      How likely are you to recommend this airline?
# 0                                                6
# 1                                               10
# 2                                               10
# 3                                                9
# 4                                                7
# ..                                             ...
# 179                                              5
# 180                                              8
# 181                                              7
# 182                                              7
# 183                                             10
#
# [5907 rows x 3 columns]

# %% [markdown]
# ### Exclude any airlines who have had less than 50 customers respond

# %%
# Filter out airlines with less than 3 responses
df_main = df_main.groupby('Airline').filter(lambda x: len(x) >= 50)
df_main
# Out:
#                             Airline CustomerID  \
# 0    Schmeler, Schimmel and Collier    013d950
# 1    Schmeler, Schimmel and Collier    0d25185
# 2    Schmeler, Schimmel and Collier    a1b541d
# 3    Schmeler, Schimmel and Collier    6b24ea8
# 4    Schmeler, Schimmel and Collier    d5f96ab
# ..                              ...        ...
# 179                        Prep Air    afa8aec
# 180                        Prep Air    63e95db
# 181                        Prep Air    e4e2548
# 182                        Prep Air    b9467ee
# 183                        Prep Air    08d8adc
#
#      How likely are you to recommend this airline?
# 0                                                6
# 1                                               10
# 2                                               10
# 3                                                9
# 4                                                7
# ..                                             ...
# 179                                              5
# 180                                              8
# 181                                              7
# 182                                              7
# 183                                             10
#
# [4762 rows x 3 columns]

# %% [markdown]
# ### Classify customer responses to the question in the following way:
# - 0-6 = Detractors
# - 7-8 = Passive
# - 9-10 = Promoters

# %%
# Define the bins and labels for classification
bins = [0,6,8,10]
labels = ['Detractors', 'Passive', 'Promoters']

# Create a new column 'Classification' based on the bins and labels
df_main['Classification'] = pd.cut(df_main['How likely are you to recommend this airline?'], bins=bins, labels=labels, include_lowest=True)
df_main
# Out:
#                             Airline CustomerID  \
# 0    Schmeler, Schimmel and Collier    013d950
# 1    Schmeler, Schimmel and Collier    0d25185
# 2    Schmeler, Schimmel and Collier    a1b541d
# 3    Schmeler, Schimmel and Collier    6b24ea8
# 4    Schmeler, Schimmel and Collier    d5f96ab
# ..                              ...        ...
# 179                        Prep Air    afa8aec
# 180                        Prep Air    63e95db
# 181                        Prep Air    e4e2548
# 182                        Prep Air    b9467ee
# 183                        Prep Air    08d8adc
#
#      How likely are you to recommend this airline? Classification
# 0                                                6     Detractors
# 1                                               10      Promoters
# 2                                               10      Promoters
# 3                                                9      Promoters
# 4                                                7        Passive
# ..                                             ...            ...
# 179                                              5     Detractors
# 180                                              8        Passive
# 181                                              7        Passive
# 182                                              7        Passive
# 183                                             10      Promoters
#
# [4762 rows x 4 columns]

# %% [markdown]
# ### Calculate the NPS for each airline
# - NPS = % Promoters - % Detractors
# - Note: I rounded the %s down to the nearest whole number, so if your answer differs slightly from mine then this could be why!

# %%
df_nps = df_main.groupby(['Airline','Classification'], as_index=False).size()
df_nps[df_nps['Airline']=='Prep Air']
# Out:
#       Airline Classification  size
# 126  Prep Air     Detractors    35
# 127  Prep Air        Passive    75
# 128  Prep Air      Promoters    74

# %%
df_nps = df_nps.pivot(index='Airline', columns='Classification', values = 'size').reset_index().rename_axis(None, axis=1)
df_nps['Total'] = df_nps['Detractors'] + df_nps['Passive'] + df_nps['Promoters']

df_nps['Promoters%'] = np.floor(df_nps['Promoters']/df_nps['Total']*100)
df_nps['Detractors%'] = np.floor(df_nps['Detractors']/df_nps['Total']*100)
df_nps['NPS'] = df_nps['Promoters%'] - df_nps['Detractors%']
df_nps['NPS'] = df_nps['NPS'].astype(int)

df_nps
# Out:
#                                Airline  Detractors  Passive  Promoters  Total  \
# 0              Abbott, Boyle and Morar          15       22         23     60
# 1       Abbott, Gutkowski and Cummings          29       41         31    101
# 2                        Abshire Group          24       32         35     91
# 3                        Bayer-Collier          23       37         28     88
# 4             Bernhard, Ernser and Toy          20       32         30     82
# 5                            Blick Inc          31       31         31     93
# 6                       Bogan and Sons          32       53         27    112
# 7             Bogan, Barrows and Morar          21       31         31     83
# 8                      Brakus-Weissnat          14       21         17     52
# 9                           Brekke Inc          17       29         18     64
# 10                  Buckridge and Sons          20       31         25     76
# 11  Cartwright, Gislason and Kertzmann          24       40         39    103
# 12                         Crist Group          14       28         30     72
# 13     Cronin, O'Keefe and Heidenreich          26       32         26     84
# 14           Daniel, Streich and Nolan          14       37         29     80
# 15      Daugherty, Heaney and Connelly          27       24         28     79
# 16                    Farrell and Sons          10       21         24     55
# 17                     Gleichner Group          18       17         20     55
# 18                     Gottlieb-Paucek          18       34         24     76
# 19                         Goyette Inc          21       24         38     83
# 20                       Halvorson Inc          17       29         29     75
# 21             Hamill, Koepp and Robel          12       22         18     52
# 22                         Hand-Maggio          31       48         52    131
# 23                Hodkiewicz-Jaskolski          18       29         20     67
# 24                           Hoppe Inc          23       24         37     84
# 25                          Jast Group          16       31         26     73
# 26                   Kautzer-Langworth          11       19         31     61
# 27                      Kerluke-Murphy          23       29         21     73
# 28                    Kutch-Vandervort          20       23         17     60
# 29                         Lakin-Crona          17       26         26     69
# 30                      Lesch and Sons          18       28         20     66
# 31                        Lindgren LLC          15       36         32     83
# 32                         Lynch-Welch          19       22         29     70
# 33                        Maggio Group           5       25         27     57
# 34                      Marks and Sons          27       39         40    106
# 35                      Mayer-Shanahan          32       29         32     93
# 36                        Mitchell Inc          25       31         27     83
# 37                       Mueller Group          12       18         28     58
# 38                           Nader LLC          19       20         17     56
# 39         Nicolas, Boyer and Botsford          21       30         31     82
# 40                         Okuneva Inc          25       31         24     80
# 41                    Parisian-Kovacek          27       27         37     91
# 42                            Prep Air          35       75         74    184
# 43                       Reinger Group          21       18         16     55
# 44            Reynolds, Wolf and Kunde          36       49         46    131
# 45        Rohan, Buckridge and Reichel          29       39         42    110
# 46                     Satterfield Inc          14       17         21     52
# 47      Schmeler, Schimmel and Collier          15       21         29     65
# 48         Schulist, Adams and Hilpert          48       56         64    168
# 49                         Simonis Inc          14       17         20     51
# 50                    Smitham-Reichert          30       24         35     89
# 51                    Stracke and Sons          10       26         25     61
# 52         Toy, Bartell and Williamson          14       17         21     52
# 53               Toy, Will and Goyette          17       26         21     64
# 54                Von, Brown and Frami          26       51         52    129
# 55                           Walsh LLC          16       15         19     50
# 56                       West and Sons          36       30         33     99
# 57                      Williamson LLC          24       28         26     78
# 58              Wyman, Bruen and Thiel          17       28         20     65
#
#     Promoters%  Detractors%  NPS
# 0         38.0         25.0   13
# 1         30.0         28.0    2
# 2         38.0         26.0   12
# 3         31.0         26.0    5
# 4         36.0         24.0   12
# 5         33.0         33.0    0
# 6         24.0         28.0   -4
# 7         37.0         25.0   12
# 8         32.0         26.0    6
# 9         28.0         26.0    2
# 10        32.0         26.0    6
# 11        37.0         23.0   14
# 12        41.0         19.0   22
# 13        30.0         30.0    0
# 14        36.0         17.0   19
# 15        35.0         34.0    1
# 16        43.0         18.0   25
# 17        36.0         32.0    4
# 18        31.0         23.0    8
# 19        45.0         25.0   20
# 20        38.0         22.0   16
# 21        34.0         23.0   11
# 22        39.0         23.0   16
# 23        29.0         26.0    3
# 24        44.0         27.0   17
# 25        35.0         21.0   14
# 26        50.0         18.0   32
# 27        28.0         31.0   -3
# 28        28.0         33.0   -5
# 29        37.0         24.0   13
# 30        30.0         27.0    3
# 31        38.0         18.0   20
# 32        41.0         27.0   14
# 33        47.0          8.0   39
# 34        37.0         25.0   12
# 35        34.0         34.0    0
# 36        32.0         30.0    2
# 37        48.0         20.0   28
# 38        30.0         33.0   -3
# 39        37.0         25.0   12
# 40        30.0         31.0   -1
# 41        40.0         29.0   11
# 42        40.0         19.0   21
# 43        29.0         38.0   -9
# 44        35.0         27.0    8
# 45        38.0         26.0   12
# 46        40.0         26.0   14
# 47        44.0         23.0   21
# 48        38.0         28.0   10
# 49        39.0         27.0   12
# 50        39.0         33.0    6
# 51        40.0         16.0   24
# 52        40.0         26.0   14
# 53        32.0         26.0    6
# 54        40.0         20.0   20
# 55        38.0         32.0    6
# 56        33.0         36.0   -3
# 57        33.0         30.0    3
# 58        30.0         26.0    4

# %% [markdown]
# ### Calculate the average and standard deviation of the dataset

# %%
df_stat = df_nps['NPS'].agg({'average':'mean',"standard deviation": 'std'})
df_stat
# Out:
# average               10.152542
# standard deviation     9.648680
# Name: NPS, dtype: float64

# %% [markdown]
# ### Take each airline's NPS and subtract the average, then divide this by the standard deviation

# %%
df_nps['Z-Score'] = (df_nps['NPS'] - df_stat['average'])/df_stat['standard deviation']
df_nps
# Out:
#                                Airline  Detractors  Passive  Promoters  Total  \
# 0              Abbott, Boyle and Morar          15       22         23     60
# 1       Abbott, Gutkowski and Cummings          29       41         31    101
# 2                        Abshire Group          24       32         35     91
# 3                        Bayer-Collier          23       37         28     88
# 4             Bernhard, Ernser and Toy          20       32         30     82
# 5                            Blick Inc          31       31         31     93
# 6                       Bogan and Sons          32       53         27    112
# 7             Bogan, Barrows and Morar          21       31         31     83
# 8                      Brakus-Weissnat          14       21         17     52
# 9                           Brekke Inc          17       29         18     64
# 10                  Buckridge and Sons          20       31         25     76
# 11  Cartwright, Gislason and Kertzmann          24       40         39    103
# 12                         Crist Group          14       28         30     72
# 13     Cronin, O'Keefe and Heidenreich          26       32         26     84
# 14           Daniel, Streich and Nolan          14       37         29     80
# 15      Daugherty, Heaney and Connelly          27       24         28     79
# 16                    Farrell and Sons          10       21         24     55
# 17                     Gleichner Group          18       17         20     55
# 18                     Gottlieb-Paucek          18       34         24     76
# 19                         Goyette Inc          21       24         38     83
# 20                       Halvorson Inc          17       29         29     75
# 21             Hamill, Koepp and Robel          12       22         18     52
# 22                         Hand-Maggio          31       48         52    131
# 23                Hodkiewicz-Jaskolski          18       29         20     67
# 24                           Hoppe Inc          23       24         37     84
# 25                          Jast Group          16       31         26     73
# 26                   Kautzer-Langworth          11       19         31     61
# 27                      Kerluke-Murphy          23       29         21     73
# 28                    Kutch-Vandervort          20       23         17     60
# 29                         Lakin-Crona          17       26         26     69
# 30                      Lesch and Sons          18       28         20     66
# 31                        Lindgren LLC          15       36         32     83
# 32                         Lynch-Welch          19       22         29     70
# 33                        Maggio Group           5       25         27     57
# 34                      Marks and Sons          27       39         40    106
# 35                      Mayer-Shanahan          32       29         32     93
# 36                        Mitchell Inc          25       31         27     83
# 37                       Mueller Group          12       18         28     58
# 38                           Nader LLC          19       20         17     56
# 39         Nicolas, Boyer and Botsford          21       30         31     82
# 40                         Okuneva Inc          25       31         24     80
# 41                    Parisian-Kovacek          27       27         37     91
# 42                            Prep Air          35       75         74    184
# 43                       Reinger Group          21       18         16     55
# 44            Reynolds, Wolf and Kunde          36       49         46    131
# 45        Rohan, Buckridge and Reichel          29       39         42    110
# 46                     Satterfield Inc          14       17         21     52
# 47      Schmeler, Schimmel and Collier          15       21         29     65
# 48         Schulist, Adams and Hilpert          48       56         64    168
# 49                         Simonis Inc          14       17         20     51
# 50                    Smitham-Reichert          30       24         35     89
# 51                    Stracke and Sons          10       26         25     61
# 52         Toy, Bartell and Williamson          14       17         21     52
# 53               Toy, Will and Goyette          17       26         21     64
# 54                Von, Brown and Frami          26       51         52    129
# 55                           Walsh LLC          16       15         19     50
# 56                       West and Sons          36       30         33     99
# 57                      Williamson LLC          24       28         26     78
# 58              Wyman, Bruen and Thiel          17       28         20     65
#
#     Promoters%  Detractors%  NPS   Z-Score
# 0         38.0         25.0   13  0.295114
# 1         30.0         28.0    2 -0.844939
# 2         38.0         26.0   12  0.191473
# 3         31.0         26.0    5 -0.534015
# 4         36.0         24.0   12  0.191473
# 5         33.0         33.0    0 -1.052221
# 6         24.0         28.0   -4 -1.466785
# 7         37.0         25.0   12  0.191473
# 8         32.0         26.0    6 -0.430374
# 9         28.0         26.0    2 -0.844939
# 10        32.0         26.0    6 -0.430374
# 11        37.0         23.0   14  0.398755
# 12        41.0         19.0   22  1.227884
# 13        30.0         30.0    0 -1.052221
# 14        36.0         17.0   19  0.916960
# 15        35.0         34.0    1 -0.948580
# 16        43.0         18.0   25  1.538807
# 17        36.0         32.0    4 -0.637656
# 18        31.0         23.0    8 -0.223092
# 19        45.0         25.0   20  1.020602
# 20        38.0         22.0   16  0.606037
# 21        34.0         23.0   11  0.087831
# 22        39.0         23.0   16  0.606037
# 23        29.0         26.0    3 -0.741298
# 24        44.0         27.0   17  0.709678
# 25        35.0         21.0   14  0.398755
# 26        50.0         18.0   32  2.264295
# 27        28.0         31.0   -3 -1.363144
# 28        28.0         33.0   -5 -1.570427
# 29        37.0         24.0   13  0.295114
# 30        30.0         27.0    3 -0.741298
# 31        38.0         18.0   20  1.020602
# 32        41.0         27.0   14  0.398755
# 33        47.0          8.0   39  2.989783
# 34        37.0         25.0   12  0.191473
# 35        34.0         34.0    0 -1.052221
# 36        32.0         30.0    2 -0.844939
# 37        48.0         20.0   28  1.849731
# 38        30.0         33.0   -3 -1.363144
# 39        37.0         25.0   12  0.191473
# 40        30.0         31.0   -1 -1.155862
# 41        40.0         29.0   11  0.087831
# 42        40.0         19.0   21  1.124243
# 43        29.0         38.0   -9 -1.984991
# 44        35.0         27.0    8 -0.223092
# 45        38.0         26.0   12  0.191473
# 46        40.0         26.0   14  0.398755
# 47        44.0         23.0   21  1.124243
# 48        38.0         28.0   10 -0.015810
# 49        39.0         27.0   12  0.191473
# 50        39.0         33.0    6 -0.430374
# 51        40.0         16.0   24  1.435166
# 52        40.0         26.0   14  0.398755
# 53        32.0         26.0    6 -0.430374
# 54        40.0         20.0   20  1.020602
# 55        38.0         32.0    6 -0.430374
# 56        33.0         36.0   -3 -1.363144
# 57        33.0         30.0    3 -0.741298
# 58        30.0         26.0    4 -0.637656

# %% [markdown]
# ### Filter to just show Prep Air's NPS along with their Z-Score

# %%
dt_output = df_nps[df_nps['Airline']=='Prep Air']
dt_output = dt_output[['Airline','NPS','Z-Score']]
dt_output
# Out:
#      Airline  NPS   Z-Score
# 42  Prep Air   21  1.124243

# %% [markdown]
# ### Output the data

# %%
dt_output.to_csv(r'output/2021-week23-output.csv')
