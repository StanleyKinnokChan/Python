# %%
# https://preppindata.blogspot.com/2023/07/2023-week-28-prep-school-track-team.html

import pandas as pd
import numpy as np
from datetime import date

# %% [markdown]
# ### Input the data

# %%
df_students = pd.read_excel(r'data\PD 2023 Wk 28 Input.xlsx', sheet_name='Students')
df_times = pd.read_excel(r'data\PD 2023 Wk 28 Input.xlsx', sheet_name='Track Times')
df_benchmarks = pd.read_excel(r'data\PD 2023 Wk 28 Input.xlsx', sheet_name='Benchmarks')
df_students
# Out:
#       id first_name   last_name gender  age
# 0      1      Jesse       Motto      M   10
# 1      2    Wendall      Banger      M   10
# 2      3      Iosep   Wateridge      M   11
# 3      4     Larina      Thomas      F    8
# 4      5      Linzy      Barock      F   11
# ..   ...        ...         ...    ...  ...
# 295  296      Tonya    Milleton      F   11
# 296  297      Tyson    Connealy      M   10
# 297  298      Hilde  Vanyashkin      F   10
# 298  299    Miranda      Ropert      F    8
# 299  300       Yale      Le Leu      M   11
#
# [300 rows x 5 columns]

# %% [markdown]
# ### Join the students basic information with their event and track time

# %%
df_times.columns
# Out:
# Index(['id', 'track_event', 'time'], dtype='object')

# %%
df_stu_track = pd.merge(df_students,df_times,on='id')
df_stu_track
# Out:
#       id first_name   last_name gender  age track_event   time
# 0      1      Jesse       Motto      M   10        200m  32.39
# 1      2    Wendall      Banger      M   10        200m  39.78
# 2      3      Iosep   Wateridge      M   11        100m  15.39
# 3      4     Larina      Thomas      F    8        200m  18.10
# 4      5      Linzy      Barock      F   11        200m  27.00
# ..   ...        ...         ...    ...  ...         ...    ...
# 295  296      Tonya    Milleton      F   11        100m  19.62
# 296  297      Tyson    Connealy      M   10        100m  19.93
# 297  298      Hilde  Vanyashkin      F   10        200m  21.60
# 298  299    Miranda      Ropert      F    8        100m  17.23
# 299  300       Yale      Le Leu      M   11        200m  44.40
#
# [300 rows x 7 columns]

# %% [markdown]
# ### Join the benchmark table with the right students
# - Note: the number of rows should still be 300 after the join

# %%
df_benchmarks.columns
# Out:
# Index(['Gender ', 'Age ', 'Event ', 'Benchmark'], dtype='object')

# %%
df_stu_track_bench = pd.merge(df_stu_track,df_benchmarks,left_on=['gender','age','track_event'],right_on=['Gender ', 'Age ', 'Event '],how='inner')
df_stu_track_bench
# Out:
#       id first_name  last_name gender  age track_event   time Gender   Age   \
# 0      1      Jesse      Motto      M   10        200m  32.39       M    10
# 1      2    Wendall     Banger      M   10        200m  39.78       M    10
# 2     22     Dallas  Ratchford      M   10        200m  24.58       M    10
# 3     45   Jefferey     Cubley      M   10        200m  34.05       M    10
# 4     77       Eben  McPeeters      M   10        200m  15.99       M    10
# ..   ...        ...        ...    ...  ...         ...    ...     ...   ...
# 295  194    Madelin    Kenelin      F    9        100m  44.82       F     9
# 296  206     Bertie   Brettell      F    9        100m  42.28       F     9
# 297  216    Jordana       Lear      F    9        100m  38.59       F     9
# 298  261      Sally      Barca      F    9        100m  20.31       F     9
# 299  295      Ailee  Pallister      F    9        100m  15.95       F     9
#
#     Event   Benchmark
# 0     200m       29.0
# 1     200m       29.0
# 2     200m       29.0
# 3     200m       29.0
# 4     200m       29.0
# ..     ...        ...
# 295   100m       15.5
# 296   100m       15.5
# 297   100m       15.5
# 298   100m       15.5
# 299   100m       15.5
#
# [300 rows x 11 columns]

# %% [markdown]
# ### Filter out the students that did not fall within the benchmark

# %%
df_stu_track_bench = df_stu_track_bench[df_stu_track_bench['time']<=df_stu_track_bench['Benchmark']]
df_stu_track_bench.columns
# Out:
# Index(['id', 'first_name', 'last_name', 'gender', 'age', 'track_event', 'time',
#        'Gender ', 'Age ', 'Event ', 'Benchmark'],
#       dtype='object')

# %%
df_stu_track_bench
# Out:
#       id first_name  last_name gender  age track_event   time Gender   Age   \
# 2     22     Dallas  Ratchford      M   10        200m  24.58       M    10
# 4     77       Eben  McPeeters      M   10        200m  15.99       M    10
# 5     83      Kevon     Hannum      M   10        200m  25.05       M    10
# 7    122     Corbie    Phython      M   10        200m  21.93       M    10
# 8    132      Alwyn      Askaw      M   10        200m  20.44       M    10
# ..   ...        ...        ...    ...  ...         ...    ...     ...   ...
# 279  230     Buiron    Attreed      M    9        200m  21.28       M     9
# 281  239     Willey       Joye      M    9        200m  24.18       M     9
# 282  240    Robbert     Mingay      M    9        200m  21.63       M     9
# 286  269   Barbabas     Horick      M    9        200m  29.65       M     9
# 287  271      Orran   Jentgens      M    9        200m  15.65       M     9
#
#     Event   Benchmark
# 2     200m       29.0
# 4     200m       29.0
# 5     200m       29.0
# 7     200m       29.0
# 8     200m       29.0
# ..     ...        ...
# 279   200m       30.0
# 281   200m       30.0
# 282   200m       30.0
# 286   200m       30.0
# 287   200m       30.0
#
# [80 rows x 11 columns]

# %% [markdown]
# ### There has been an error with the collection of the times, so remove any 200m times that fall below 25 seconds

# %%
# Filtering out rows with time less than 25 seconds for the 200m track event
df_output = df_stu_track_bench[~((df_stu_track_bench['track_event'] == '200m') & (df_stu_track_bench['time'] < 25))]

# %% [markdown]
# ### Rank the students fastest to slowest for each event

# %%
df_output['Rank'] = df_output.groupby('track_event')['time'].rank().astype(int)
df_output = df_output.sort_values(by='Rank')
df_output
# Out:
# C:\Users\StanleyChan\AppData\Local\Temp\ipykernel_26856\1824852499.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_output['Rank'] = df_output.groupby('track_event')['time'].rank().astype(int)
#       id first_name     last_name gender  age track_event   time Gender   \
# 5     83      Kevon        Hannum      M   10        200m  25.05       M
# 189  127     Gradey        Slevin      M    9        100m  14.31       M
# 79     6      Ganny        Blouet      M    8        100m  14.31       M
# 109  262     Parker        Texton      M    8        200m  25.51       M
# 134  236    Celeste       Kendred      F    8        100m  14.43       F
# 269  100     Brodie        Terris      M    9        200m  25.81       M
# 100   99      Ogden    Scammonden      M    8        200m  25.92       M
# 110  263    Randall  Valentinetti      M    8        200m  26.02       M
# 148  131     Silvia       Viggers      F   10        200m  26.13       F
# 139   14    Arliene        Bonsul      F   10        200m  26.64       F
# 64     5      Linzy        Barock      F   11        200m  27.00       F
# 108  255        Ira       Gabbatt      M    8        200m  27.06       M
# 166  148    Matilde      Andersch      F    9        200m  27.12       F
# 69    82     Sherie        Cluatt      F   11        200m  27.56       F
# 51   157       Zena       Duckers      F    8        200m  27.79       F
# 77   207     Danila     Spiniello      F   11        200m  27.85       F
# 70   104       Faun       Gebhard      F   11        200m  27.87       F
# 151  185     Sheree      Wedgwood      F   10        200m  27.99       F
# 75   144       Angy         Wyeth      F   11        200m  28.01       F
# 153  195     Darcey        Cordon      F   10        200m  28.04       F
# 55   184     Bobina    Simoncelli      F    8        200m  28.33       F
# 56   202     Kelsey    Fearnsides      F    8        200m  28.57       F
# 61   282     Maggie    Potteridge      F    8        200m  28.60       F
# 156  254      Carri      Skellern      F   10        200m  28.78       F
# 72   113      Gipsy       O'Regan      F   11        200m  28.86       F
# 159  287     Jessie      Lindborg      F   10        200m  29.20       F
# 286  269   Barbabas        Horick      M    9        200m  29.65       M
# 162   49    Garland       Pimbley      F    9        200m  29.71       F
# 97    60     Rowney       Tidbold      M    8        200m  29.89       M
# 96    55     Brnaba        Fatkin      M    8        200m  30.37       M
# 63   286      Bessy          Dand      F    8        200m  30.74       F
#
#      Age  Event   Benchmark  Rank
# 5      10   200m       29.0     1
# 189     9   100m       14.5     1
# 79      8   100m       15.0     1
# 109     8   200m       31.0     2
# 134     8   100m       16.0     3
# 269     9   200m       30.0     3
# 100     8   200m       31.0     4
# 110     8   200m       31.0     5
# 148    10   200m       30.0     6
# 139    10   200m       30.0     7
# 64     11   200m       29.0     8
# 108     8   200m       31.0     9
# 166     9   200m       31.0    10
# 69     11   200m       29.0    11
# 51      8   200m       32.0    12
# 77     11   200m       29.0    13
# 70     11   200m       29.0    14
# 151    10   200m       30.0    15
# 75     11   200m       29.0    16
# 153    10   200m       30.0    17
# 55      8   200m       32.0    18
# 56      8   200m       32.0    19
# 61      8   200m       32.0    20
# 156    10   200m       30.0    21
# 72     11   200m       29.0    22
# 159    10   200m       30.0    23
# 286     9   200m       30.0    24
# 162     9   200m       31.0    25
# 97      8   200m       31.0    26
# 96      8   200m       31.0    27
# 63      8   200m       32.0    28

# %% [markdown]
# ### Output the data

# %%
df_output.to_csv(r'output/2023-week28-output.csv')
