# %%
from sqlalchemy import create_engine
import csv

# %%
df = pd.read_excel(r"C:\Users\StanleyChan\SynologyDrive\Work Backup\my document\Test\Olympic Event Schedule.xlsx",sheet_name='Event Schedule')
df
# Out:
#        Latitude   Longitude  Medal Ceremony? Sport Group  \
# 0     35.677864  139.713663            False    Ceremony
# 1     35.677864  139.713663            False    Ceremony
# 2     35.677864  139.713663            False   Athletics
# 3     35.677864  139.713663            False   Athletics
# 4     35.677864  139.713663            False   Athletics
# ...         ...         ...              ...         ...
# 1890  35.903409  139.718166            False    Football
# 1891  35.510025  139.606877            False    Football
# 1892  35.510025  139.606877            False    Football
# 1893  35.510025  139.606877            False    Football
# 1894  35.510025  139.606877            False    Football
#
#                                       Events Split        UK Date Time  \
# 0                                                - 2021-07-23 12:00:00
# 1                                                - 2021-08-08 12:00:00
# ...

# %%
start_time = time.time()
df.query("`Sport Group` == 'Football'")
end_time = time.time()
running_time = end_time - start_time
print("Running time: {:.2f} seconds".format(running_time))
# Out:
# Running time: 0.00 seconds
